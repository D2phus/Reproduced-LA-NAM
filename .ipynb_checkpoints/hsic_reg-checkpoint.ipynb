# %%
from LANAM.models import  NAM, LaNAM
from LANAM.trainer import *
from LANAM.trainer.nam_trainer import train
from LANAM.trainer import test
from LANAM.config.default import * 
from LANAM.data import *
from LANAM.data.base import LANAMDataset, LANAMSyntheticDataset
from LANAM.utils.plotting import * 
from LANAM.utils.regularizer import *

import matplotlib.pyplot as plt
import seaborn as sns
import copy

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
data = load_nonlinearly_dependent_2D_examples(num_samples=500)
data.plot_dataset()

# %% [markdown]
# ### interaction examples

# %%
def generate_interaction_example(rho, min_max=True): 
    # rho = 0, 0.7, 0.9, 0.95, 0.99
    data = interaction_example(rho=rho, min_max=min_max)


    input_0, input_1 = data.features.T
    target = data.targets
    
    plt.figure(figsize=(4, 4))
    plt.scatter(input_0, input_1)
    plt.xlabel('input_0')
    plt.ylabel('input_1')
    plot_3d(input_0, input_1, target)
    
    return data

# %%
data = generate_interaction_example(rho=0.99)
in_features = data.in_features
train_dl, train_dl_fnn, val_dl, val_fnn = data.train_dataloaders()
test_samples = data.get_test_samples()

# %%
cfg = toy_default()
# cfg.output_regularization = 0.05
cfg.log_loss_frequency = 100
# cfg.concurvity_regularization = 2
cfg.hsic_regularization = 2

cfg.num_ensemble = 5
cfg.num_epochs = 300
cfg.early_stopping_patience = 100
con_wo_model = train(config=cfg, train_loader=train_dl, val_loader=val_dl, test_samples=test_samples, ensemble=False)

# %%
lanam_cfg = defaults()
lanam = LaNAM(config=lanam_cfg, name="LA-NAM", in_features=in_features, hessian_structure='kron', subset_of_weights='last_layer')
lanam, margs, losses, perfs = marglik_training(lanam, 
                                                   train_dl, 
                                                   train_dl_fnn, 
                                                   val_dl, 
                                                   likelihood='regression', 
                                                   test_samples=test_samples,
                                                   n_epochs=300, 
                                                   use_wandb=False, 
                                                   optimizer_kwargs={'lr': 1e-2}, 
                                                   n_hypersteps=100, 
                                                   reg_perctile_epochs_burnin=0, 
                                                   prior_prec_init=[1, 1], 
                                                   hsic_regularization=5)
    
X, y, shape_functions, names = test_samples
prediction_mean, feature_contribution_mean, prediction_mean, feature_contribution_var = get_prediction(lanam, test_samples)
importance_fig = plot_feature_importance(lanam, test_samples)
recover_fig = plot_recovered_functions(X, y, shape_functions, feature_contribution_mean, feature_contribution_var.flatten(start_dim=1), center=False)       
    # print(X.shape)
plot_3d(X[:, 0], X[:, 1], prediction_mean, y)

# %% [markdown]
# ### nonlinear 2D examples
# non-identifiability.

# %%
perfect_correlated_data = load_nonlinearly_dependent_2D_examples(
                                                      num_samples=1000, 
                                                      sigma=0, 
                                                      sampling_type='uniform', 
                                                      dependent_functions=lambda x: torch.sin(3*x)) # perfectly correlated features 
pc_train_dl, _, pc_val_dl, _ = perfect_correlated_data.train_dataloaders()
pc_test_samples = perfect_correlated_data.get_test_samples()
perfect_correlated_data.plot_dataset()

# %%
cfg = toy_default()
# cfg.output_regularization = 0.05
cfg.log_loss_frequency = 100
cfg.hsic_regularization = 1
cfg.num_ensemble = 5
cfg.num_epochs = 200
cfg.early_stopping_patience = 20
con_wo_model = train(config=cfg, train_loader=pc_train_dl, val_loader=pc_val_dl, test_samples=pc_test_samples, ensemble=False)
# Out:
# [EPOCH=98]: Early stopping with Val_Loss:  0.017231, Val_RMSE:  0.001638, Val_R_perp:  0.535329
# R_squared:  0.9996

# %% [markdown]
# ### concurvity examples
# $$
# X_1 \sim X_2 \sim X_3 \sim U(0,1)\\
# X_4 = X_2^3 + X_3 ^ 2 + \sigma_1\\
# X_5 = X_3^2+\sigma_1\\
# X_6 = X_2^2 + X_4^3+\sigma_1 \\
# X_7 = X_1 \times X_4 +\sigma_1\\
# Y = 2X_1^2 + X_5^3 + 2\sin X_6+\sigma_2
# $$

# %%
concurvity_data = load_concurvity_data(sigma_1=0.05, sigma_2=0.5, num_samples=1000)
con_train_dl, con_train_dl_fnn, con_val_dl, _ = concurvity_data.train_dataloaders()
con_test_samples = concurvity_data.get_test_samples()
concurvity_data.plot_dataset()
# concurvity_data.plot_scatterplot_matrix()
# Out:
# torch.Size([1000, 7])

# %% [markdown]
# #### No regularization

# %%
cfg = toy_default()
cfg.log_loss_frequency = 100
cfg.concurvity_regularization = 0
cfg.num_epochs = 400
cfg.early_stopping_patience = 20
con_wo_model = train(config=cfg, train_loader=con_train_dl, val_loader=con_val_dl, test_samples=con_test_samples, ensemble=False)
# Out:
# [EPOCH=69]: Early stopping with Val_Loss:  0.274491, Val_RMSE:  0.274491, Val_R_perp:  0.287572
# R_squared:  0.8193

# %%
cfg = defaults()
lanam = LaNAM(config=cfg, name="LA-NAM", in_features=concurvity_data.in_features, hessian_structure='kron', subset_of_weights='last_layer')

lanam, margs, losses, perfs = marglik_training(lanam, 
                                               con_train_dl, 
                                               con_train_dl_fnn, 
                                               con_val_dl, 
                                               likelihood='regression', 
                                               test_samples=con_test_samples,
                                               n_epochs=400, 
                                               use_wandb=False, 
                                               optimizer_kwargs={'lr': 1e-2})
# Out:
# [Epoch=100, Train_RMSE:  0.542, Train_R_perp:  0.166, Val_RMSE:  0.175, Val_R_perp:  0.020, n_hypersteps=29]: observed noise= 0.610, prior precision=tensor([4.4106, 4.1738, 4.6711, 4.0366, 4.3798, 2.9576, 4.6228])
# [Epoch=200, Train_RMSE:  0.511, Train_R_perp:  0.146, Val_RMSE:  0.177, Val_R_perp:  0.016, n_hypersteps=29]: observed noise= 0.499, prior precision=tensor([ 6.1982,  5.2831, 17.7435,  3.7836,  7.4876,  1.3160, 16.7363])
# [Epoch=300, Train_RMSE:  0.517, Train_R_perp:  0.109, Val_RMSE:  0.170, Val_R_perp:  0.009, n_hypersteps=29]: observed noise= 0.511, prior precision=tensor([ 4.2202,  4.1223, 58.4746,  3.5113,  5.3056,  1.2835, 49.5193])
# [Epoch=400, Train_RMSE:  0.501, Train_R_perp:  0.088, Val_RMSE:  0.170, Val_R_perp:  0.009, n_hypersteps=29]: observed noise= 0.500, prior precision=tensor([  4.4359,   3.9858, 146.1947,   4.2773,   6.7560,   1.2670, 125.0772])
# MARGLIK: finished training. Recover best model and fit Laplace.

# %%
X_test, y_test, fnn_test, _ = con_test_samples
f_mu, f_var, f_mu_fnn, f_var_fnn = lanam.predict(X_test)

importance_fig = plot_feature_importance(lanam, con_test_samples)

recover_fig = plot_recovered_functions(X_test, y_test, fnn_test, f_mu_fnn, f_var_fnn.flatten(start_dim=1), center=False)

# %% [markdown]
# #### HSIC regularization

# %%
cfg = toy_default()
cfg.log_loss_frequency = 100
cfg.concurvity_regularization = 0
cfg.num_epochs = 400
cfg.early_stopping_patience = 20
cfg.hsic_regularization = 10
con_wo_model = train(config=cfg, train_loader=con_train_dl, val_loader=con_val_dl, test_samples=con_test_samples, ensemble=False)
# Out:
# [EPOCH=54]: Early stopping with Val_Loss:  0.405639, Val_RMSE:  0.295802, Val_R_perp:  0.226040
# R_squared:  0.8151

# %%
ls = [1e-1, 0.5, 1, 1.5, 2]
for l in ls:
    print(f'hsic regularization: {l}')
    cfg = defaults()
    lanam = LaNAM(config=cfg, name="LA-NAM", in_features=concurvity_data.in_features, hessian_structure='kron', subset_of_weights='last_layer')

    lanam, margs, losses, perfs = marglik_training(lanam, 
                                                   con_train_dl, 
                                                   con_train_dl_fnn, 
                                                   con_val_dl, 
                                                   likelihood='regression', 
                                                   test_samples=con_test_samples,
                                                   n_epochs=400, 
                                                    use_wandb=False, 
                                                   hsic_regularization=l, 
                                                   optimizer_kwargs={'lr': 1e-2})
    X_test, y_test, fnn_test, _ = con_test_samples
    f_mu, f_var, f_mu_fnn, f_var_fnn = lanam.predict(X_test)

    importance_fig = plot_feature_importance(lanam, con_test_samples)

    recover_fig = plot_recovered_functions(X_test, y_test, fnn_test, f_mu_fnn, f_var_fnn.flatten(start_dim=1), center=False)
# Out:
# hsic regularization: 0.1
# [Epoch=100, Train_RMSE:  0.524, Train_R_perp:  0.252, Val_RMSE:  0.178, Val_R_perp:  0.031, n_hypersteps=29]: observed noise= 0.607, prior precision=tensor([4.4047, 3.9752, 4.6300, 4.1647, 4.3989, 3.0915, 4.5959])
# [Epoch=200, Train_RMSE:  0.505, Train_R_perp:  0.175, Val_RMSE:  0.174, Val_R_perp:  0.029, n_hypersteps=29]: observed noise= 0.493, prior precision=tensor([ 8.0132,  7.6460, 17.3109,  8.9964,  7.1956,  2.4984, 16.7415])
# [Epoch=300, Train_RMSE:  0.509, Train_R_perp:  0.095, Val_RMSE:  0.174, Val_R_perp:  0.012, n_hypersteps=29]: observed noise= 0.503, prior precision=tensor([ 4.8156,  5.2250, 53.4543,  6.7390,  5.6692,  2.3663, 50.7728])
# [Epoch=400, Train_RMSE:  0.504, Train_R_perp:  0.094, Val_RMSE:  0.180, Val_R_perp:  0.011, n_hypersteps=29]: observed noise= 0.505, prior precision=tensor([  5.1624,   5.5755, 113.3661,   6.0246,   6.0280,   2.3252, 105.5795])
# MARGLIK: finished training. Recover best model and fit Laplace.
# hsic regularization: 1
# [Epoch=100, Train_RMSE:  0.518, Train_R_perp:  0.200, Val_RMSE:  0.173, Val_R_perp:  0.020, n_hypersteps=29]: observed noise= 0.606, prior precision=tensor([4.3654, 4.3127, 4.6558, 3.9830, 4.3864, 2.7496, 4.5348])
# [Epoch=200, Train_RMSE:  0.517, Train_R_perp:  0.175, Val_RMSE:  0.176, Val_R_perp:  0.018, n_hypersteps=29]: observed noise= 0.508, prior precision=tensor([ 6.3943,  7.7851, 17.2411,  4.7668,  7.2515,  2.0250, 14.1795])
# [Epoch=300, Train_RMSE:  0.506, Train_R_perp:  0.183, Val_RMSE:  0.179, Val_R_perp:  0.020, n_hypersteps=29]: observed noise= 0.497, prior precision=tensor([ 4.0660,  4.6298, 50.0206,  4.2738,  5.2162,  1.9790, 35.9424])
# [Epoch=400, Train_RMSE:  0.501, Train_R_perp:  0.097, Val_RMSE:  0.171, Val_R_perp:  0.011, n_hypersteps=29]: observed noise= 0.502, prior precision=tensor([  4.1389,   5.4961, 107.1919,   4.1284,   5.2314,   1.7742,  94.5618])
# MARGLIK: finished training. Recover best model and fit Laplace.
# hsic regularization: 1.5
# [Epoch=100, Train_RMSE:  0.521, Train_R_perp:  0.275, Val_RMSE:  0.200, Val_R_perp:  0.030, n_hypersteps=29]: observed noise= 0.606, prior precision=tensor([4.4525, 4.1889, 4.6802, 4.1884, 4.4370, 2.6457, 4.5295])
# [Epoch=200, Train_RMSE:  0.513, Train_R_perp:  0.161, Val_RMSE:  0.175, Val_R_perp:  0.026, n_hypersteps=29]: observed noise= 0.503, prior precision=tensor([ 7.8445,  7.0222, 17.8060,  6.9425,  8.3342,  2.6872,  9.5314])
# [Epoch=300, Train_RMSE:  0.504, Train_R_perp:  0.161, Val_RMSE:  0.175, Val_R_perp:  0.019, n_hypersteps=29]: observed noise= 0.495, prior precision=tensor([ 4.1755,  4.4755, 58.7137,  5.2436,  5.2665,  2.5352,  6.5398])
# [Epoch=400, Train_RMSE:  0.508, Train_R_perp:  0.171, Val_RMSE:  0.175, Val_R_perp:  0.019, n_hypersteps=29]: observed noise= 0.510, prior precision=tensor([  5.0776,   5.1477, 142.9869,   4.7478,   5.3415,   2.6728,   8.0271])
# MARGLIK: finished training. Recover best model and fit Laplace.
# hsic regularization: 2
# [Epoch=100, Train_RMSE:  0.511, Train_R_perp:  0.268, Val_RMSE:  0.181, Val_R_perp:  0.031, n_hypersteps=29]: observed noise= 0.604, prior precision=tensor([4.5272, 4.3137, 4.6036, 4.4359, 4.4075, 1.7065, 4.4399])
# [Epoch=200, Train_RMSE:  0.501, Train_R_perp:  0.257, Val_RMSE:  0.177, Val_R_perp:  0.030, n_hypersteps=29]: observed noise= 0.488, prior precision=tensor([ 9.5677,  8.6447, 16.4570,  8.0404,  8.8533,  2.2912,  9.3015])
# [Epoch=300, Train_RMSE:  0.506, Train_R_perp:  0.182, Val_RMSE:  0.178, Val_R_perp:  0.020, n_hypersteps=29]: observed noise= 0.499, prior precision=tensor([ 5.1139,  5.7952, 44.3539,  5.9254,  6.3341,  2.2942,  6.1315])
# [Epoch=400, Train_RMSE:  0.518, Train_R_perp:  0.174, Val_RMSE:  0.180, Val_R_perp:  0.020, n_hypersteps=29]: observed noise= 0.522, prior precision=tensor([ 5.7740,  6.1500, 80.8071,  6.2578,  6.7676,  2.4104,  7.2647])
# MARGLIK: finished training. Recover best model and fit Laplace.

# %%
cfg = defaults()
lanam = LaNAM(config=cfg, name="LA-NAM", in_features=concurvity_data.in_features, hessian_structure='kron', subset_of_weights='last_layer')

lanam, margs, losses, perfs = marglik_training(lanam, 
                                               con_train_dl, 
                                               con_train_dl_fnn, 
                                               con_val_dl, 
                                               likelihood='regression', 
                                               test_samples=con_test_samples,
                                               n_epochs=400, 
                                                use_wandb=False, 
                                               hsic_regularization=2, 
                                               optimizer_kwargs={'lr': 1e-2})
# Out:
# [Epoch=100, Train_RMSE:  0.521, Train_R_perp:  0.273, Val_RMSE:  0.189, Val_R_perp:  0.031, n_hypersteps=29]: observed noise= 0.606, prior precision=tensor([4.3930, 4.3649, 4.5575, 4.3878, 4.5021, 3.2067, 4.4211])
# [Epoch=200, Train_RMSE:  0.511, Train_R_perp:  0.272, Val_RMSE:  0.179, Val_R_perp:  0.030, n_hypersteps=29]: observed noise= 0.501, prior precision=tensor([ 7.8755,  8.3330, 15.6139,  8.6146, 10.9083,  2.8817,  9.0721])
# [Epoch=300, Train_RMSE:  0.506, Train_R_perp:  0.170, Val_RMSE:  0.178, Val_R_perp:  0.020, n_hypersteps=29]: observed noise= 0.498, prior precision=tensor([ 4.5883,  5.6780, 34.8578,  5.4533,  7.0251,  2.5916,  6.4447])
# [Epoch=400, Train_RMSE:  0.501, Train_R_perp:  0.171, Val_RMSE:  0.176, Val_R_perp:  0.019, n_hypersteps=29]: observed noise= 0.502, prior precision=tensor([ 5.7077,  6.7343, 43.9121,  6.5952,  6.5528,  2.4864,  7.6879])
# MARGLIK: finished training. Recover best model and fit Laplace.

# %%
X_test, y_test, fnn_test, _ = con_test_samples
f_mu, f_var, f_mu_fnn, f_var_fnn = lanam.predict(X_test)

importance_fig = plot_feature_importance(lanam, con_test_samples)

recover_fig = plot_recovered_functions(X_test, y_test, fnn_test, f_mu_fnn, f_var_fnn.flatten(start_dim=1), center=False)

# %% [markdown]
# #### concurvity regularization

# %%
cfg = toy_default()
cfg.log_loss_frequency = 100
cfg.concurvity_regularization = 0
cfg.num_epochs = 400
cfg.early_stopping_patience = 20
cfg.concurvity_regularization = 1
con_wo_model = train(config=cfg, train_loader=con_train_dl, val_loader=con_val_dl, test_samples=con_test_samples, ensemble=False)
# Out:
# [EPOCH=61]: Early stopping with Val_Loss:  0.468244, Val_RMSE:  0.290456, Val_R_perp:  0.088894
# R_squared:  0.8072

# %%
cfg = defaults()
lanam = LaNAM(config=cfg, name="LA-NAM", in_features=concurvity_data.in_features, hessian_structure='kron', subset_of_weights='last_layer')

lanam, margs, losses, perfs = marglik_training(lanam, 
                                               con_train_dl, 
                                               con_train_dl_fnn, 
                                               con_val_dl, 
                                               likelihood='regression', 
                                               test_samples=con_test_samples,
                                               n_epochs=400, 
                                               use_wandb=False, 
                                               concurvity_regularization=1, 
                                               optimizer_kwargs={'lr': 1e-2})
# Out:
# [Epoch=100, Train_RMSE:  0.522, Train_R_perp:  0.121, Val_RMSE:  0.173, Val_R_perp:  0.018, n_hypersteps=29]: observed noise= 0.606, prior precision=tensor([4.5209, 4.3599, 4.7373, 4.6879, 4.5349, 2.4927, 4.0564])
# [Epoch=200, Train_RMSE:  0.517, Train_R_perp:  0.084, Val_RMSE:  0.177, Val_R_perp:  0.010, n_hypersteps=29]: observed noise= 0.508, prior precision=tensor([ 8.1795,  6.2741, 20.0499, 14.6813, 10.5880,  2.3452,  5.7891])
# [Epoch=300, Train_RMSE:  0.500, Train_R_perp:  0.088, Val_RMSE:  0.175, Val_R_perp:  0.011, n_hypersteps=29]: observed noise= 0.490, prior precision=tensor([ 4.8002,  4.7996, 33.8206, 12.1078,  5.9174,  2.2263, 12.8116])
# [Epoch=400, Train_RMSE:  0.506, Train_R_perp:  0.084, Val_RMSE:  0.182, Val_R_perp:  0.014, n_hypersteps=29]: observed noise= 0.509, prior precision=tensor([ 5.7388,  5.4410, 18.6128,  8.5981,  6.3751,  2.1565, 11.4042])
# MARGLIK: finished training. Recover best model and fit Laplace.

# %%
X_test, y_test, fnn_test, _ = con_test_samples
f_mu, f_var, f_mu_fnn, f_var_fnn = lanam.predict(X_test)

importance_fig = plot_feature_importance(lanam, con_test_samples)

recover_fig = plot_recovered_functions(X_test, y_test, fnn_test, f_mu_fnn, f_var_fnn.flatten(start_dim=1), center=False)

# %% [markdown]
# #### L1 regularization

# %%
cfg = toy_default()
cfg.log_loss_frequency = 100
cfg.concurvity_regularization = 0
cfg.num_epochs = 400
cfg.early_stopping_patience = 20
cfg.l1_regularization = 0.01
con_wo_model = train(config=cfg, train_loader=con_train_dl, val_loader=con_val_dl, test_samples=con_test_samples, ensemble=False)
# Out:
# [EPOCH=100]: Train_Loss:  1.278678, Val_Loss:  1.474142,  Train_RMSE:  0.709457, Val_RMSE:  0.908681, Train_R_perp:  0.327426, Val_R_perp:  0.274524
# R_squared:  0.6212
# [EPOCH=200]: Train_Loss:  0.964479, Val_Loss:  1.140224,  Train_RMSE:  0.713362, Val_RMSE:  0.889632, Train_R_perp:  0.077314, Val_R_perp:  0.071793
# R_squared:  0.6181
# [EPOCH=300]: Train_Loss:  0.882411, Val_Loss:  1.078787,  Train_RMSE:  0.686262, Val_RMSE:  0.882774, Train_R_perp:  0.015835, Val_R_perp:  0.010389
# R_squared:  0.6198
# [EPOCH=400]: Train_Loss:  0.891753, Val_Loss:  1.067703,  Train_RMSE:  0.705918, Val_RMSE:  0.881869, Train_R_perp:  0.010982, Val_R_perp:  0.010382
# R_squared:  0.6195
# R_squared:  0.6195

# %%
cfg = defaults()
lanam = LaNAM(config=cfg, name="LA-NAM", in_features=concurvity_data.in_features, hessian_structure='kron', subset_of_weights='last_layer')

lanam, margs, losses, perfs = marglik_training(lanam, 
                                               con_train_dl, 
                                               con_train_dl_fnn, 
                                               con_val_dl, 
                                               likelihood='regression', 
                                               test_samples=con_test_samples,
                                               n_epochs=400, 
                                               use_wandb=False, 
                                               l1_regularization=1, 
                                               optimizer_kwargs={'lr': 1e-2})
# Out:
# [Epoch=100, Train_RMSE:  0.522, Train_R_perp:  0.257, Val_RMSE:  0.171, Val_R_perp:  0.026, n_hypersteps=29]: observed noise= 0.606, prior precision=tensor([4.4933, 4.3013, 4.6095, 4.1277, 4.3664, 2.1289, 4.5739])
# [Epoch=200, Train_RMSE:  0.506, Train_R_perp:  0.248, Val_RMSE:  0.174, Val_R_perp:  0.024, n_hypersteps=29]: observed noise= 0.494, prior precision=tensor([ 8.3672,  7.3151, 17.5610,  6.1998,  8.2654,  1.8078, 17.3569])
# [Epoch=300, Train_RMSE:  0.523, Train_R_perp:  0.107, Val_RMSE:  0.171, Val_R_perp:  0.010, n_hypersteps=29]: observed noise= 0.519, prior precision=tensor([ 5.5200,  6.8269, 57.0337,  6.2752,  6.6800,  1.6230, 58.4740])
# [Epoch=400, Train_RMSE:  0.501, Train_R_perp:  0.094, Val_RMSE:  0.184, Val_R_perp:  0.009, n_hypersteps=29]: observed noise= 0.499, prior precision=tensor([  5.8342,   7.8583, 143.8929,   6.4954,   5.5786,   1.4100, 154.1849])
# MARGLIK: finished training. Recover best model and fit Laplace.

# %%
X_test, y_test, fnn_test, _ = con_test_samples
f_mu, f_var, f_mu_fnn, f_var_fnn = lanam.predict(X_test)

importance_fig = plot_feature_importance(lanam, con_test_samples)

recover_fig = plot_recovered_functions(X_test, y_test, fnn_test, f_mu_fnn, f_var_fnn.flatten(start_dim=1), center=False)
